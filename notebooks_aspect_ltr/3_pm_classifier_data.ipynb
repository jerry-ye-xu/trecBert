# %%
import pandas as pd

# %%
df = pd.read_pickle("../data/all_ct_judgement_trials_all_years.pickle")
print(df.shape)
print(df.id.nunique())
df
# Out:
# (20968, 16)
# 17563
#           score           id  \
# 0      5.448689  NCT00112463
# 1      5.448689  NCT02839707
# 2      5.448689  NCT01065805
# 3      5.448689  NCT03026881
# 4      5.448689  NCT01523639
# ...         ...          ...
# 20963  5.557570  NCT03804580
# 20964  5.557570  NCT01846143
# 20965  5.557570  NCT03844815
# 20966  5.557570  NCT00830960
# 20967  5.557570  NCT02673450
#
#                                            brief_summary  \
# 0      This phase II trial studies how well depsipept...
# 1      This randomized phase II/III trial studies how...
# 2      The Radiotracer 18F-FLT can non-invasively ass...
# 3      Fluzoparib is an oral potent, selective PARP-1...
# 4      This multicenter randomized, placebo-controlle...
# ...                                                  ...
# 20963  Phase II, single-arm study to assess the safet...
# 20964  The purpose of this study is to learn what eff...
# 20965  The main purpose of this study is to learn abo...
# ...

# %%
df.id.nunique()
# Out:
# 17563

# %%
ctj = pd.read_pickle("../data/ctj_subset_all_years.pickle")
print(ctj.shape)
print(ctj.trec_doc_id.nunique())
ctj.head()
# Out:
# (29147, 12)
# 17572
#   demographics_desc disease_desc gene1_annotation_desc gene1_name  \
# 0               NaN          NaN                   NaN        NaN
# 1               NaN          NaN                   NaN        NaN
# 2               NaN          NaN                   NaN        NaN
# 3               NaN          NaN                   NaN        NaN
# 4               NaN          NaN                   NaN        NaN
#
#   gene2_annotation_desc gene2_name gene3_annotation_desc gene3_name  \
# 0                   NaN        NaN                   NaN        NaN
# 1                   NaN        NaN                   NaN        NaN
# 2                   NaN        NaN                   NaN        NaN
# 3                   NaN        NaN                   NaN        NaN
# 4                   NaN        NaN                   NaN        NaN
#
#   other_desc pm_rel_desc  trec_doc_id trec_topic_number
# 0        NaN      Not PM  NCT00001188                 1
# ...

# %%
ctj.set_index("trec_doc_id").to_dict()["pm_rel_desc"]
# Out:
# {'NCT00001188': 'Not PM',
#  'NCT00001189': 'Not PM',
#  'NCT00002185': 'Not PM',
#  'NCT00002466': 'Not PM',
#  'NCT00002804': 'Not PM',
#  'NCT00002822': 'Not PM',
#  'NCT00002863': 'Not PM',
#  'NCT00002898': 'Not PM',
#  'NCT00003023': 'Not PM',
#  'NCT00003052': 'Not PM',
#  'NCT00003058': 'Not PM',
#  'NCT00003212': 'Not PM',
#  'NCT00003521': 'Not PM',
#  'NCT00003718': 'Not PM',
#  'NCT00003893': 'Not PM',
#  'NCT00003939': 'Not PM',
#  'NCT00004110': 'Not PM',
#  'NCT00004123': 'Not PM',
#  'NCT00004180': 'Not PM',
#  'NCT00006260': 'Not PM',
#  'NCT00013416': 'Not PM',
#  'NCT00030784': 'Not PM',
#  'NCT00039182': 'Not PM',
#  'NCT00054496': 'Not PM',
#  'NCT00060944': 'Not PM',
#  'NCT00061984': 'Not PM',
#  'NCT00089258': 'Not PM',
#  'NCT00093080': 'Not PM',
#  'NCT00102609': 'Not PM',
#  'NCT00132496': 'Not PM',
#  'NCT00132704': 'Not PM',
#  'NCT00155805': 'Not PM',
#  'NCT00164021': 'Not PM',
#  'NCT00229086': 'Not PM',
#  'NCT00233948': 'Not PM',
# ...

# %%
len(set(ctj.set_index("trec_doc_id").to_dict()["pm_rel_desc"]))
# Out:
# 17572

# %%
ctj.drop_duplicates(subset="trec_doc_id", inplace=True, keep="first")

# %%
ctj[ctj["trec_doc_id"] == "NCT02645149"]
# Out:
#       demographics_desc   disease_desc gene1_annotation_desc  \
# 210             Matches    Not Disease                 Exact
# 1380                NaN            NaN                   NaN
# 1663            Matches          Exact       Missing Variant
# 3478           Excludes    Not Disease                 Exact
# 4582           Excludes    Not Disease          Missing Gene
# 4968      Not Discussed    Not Disease                 Exact
# 6472            Matches    Not Disease                 Exact
# 8618      Not Discussed    Not Disease                 Exact
# 9756            Matches    Not Disease     Different Variant
# 9884            Matches          Exact       Missing Variant
# 9978      Not Discussed  More Specific       Missing Variant
# 10084           Matches  More Specific                 Exact
# 10201           Matches          Exact       Missing Variant
# 10307           Matches          Exact                 Exact
# ...

# %%
ctj.groupby(["trec_doc_id"]).apply(len).reset_index().sort_values(by=0, ascending=False)
# Out:
#        trec_doc_id   0
# 13758  NCT02645149  30
# 8620   NCT01543113  27
# 7469   NCT01306045  26
# 2453   NCT00302588  26
# 11534  NCT02162641  25
# ...            ...  ..
# 6915   NCT01194466   1
# 6916   NCT01194609   1
# 6918   NCT01194960   1
# 6919   NCT01195181   1
# 8786   NCT01584960   1
#
# [17572 rows x 2 columns]

# %%
print(len(set(ctj.trec_doc_id.unique()).intersection(set(df.id.unique()))))
print(len(set(df.id.unique()).intersection(set(ctj.trec_doc_id.unique()))))
# Out:
# 17563
# 17563

# %%
check = ctj.groupby(by=["trec_doc_id", "pm_rel_desc"]).apply(len).reset_index()
check2 = check[check.duplicated(subset=["trec_doc_id"], keep=False)]
check2
# Out:
#        trec_doc_id pm_rel_desc  0
# 123    NCT00002459    Human PM  1
# 124    NCT00002459      Not PM  1
# 130    NCT00002485    Human PM  1
# 131    NCT00002485      Not PM  1
# 134    NCT00002493    Human PM  1
# ...            ...         ... ..
# 16967  NCT03104335      Not PM  2
# 16968  NCT03104439    Human PM  1
# 16969  NCT03104439      Not PM  1
# 16979  NCT03106415    Human PM  1
# 16980  NCT03106415      Not PM  1
#
# [2130 rows x 3 columns]

# %%
check2[check2.duplicated(subset=["trec_doc_id"], keep=False)]
# Out:
#        trec_doc_id pm_rel_desc  0
# 123    NCT00002459    Human PM  1
# 124    NCT00002459      Not PM  1
# 130    NCT00002485    Human PM  1
# 131    NCT00002485      Not PM  1
# 134    NCT00002493    Human PM  1
# ...            ...         ... ..
# 16967  NCT03104335      Not PM  2
# 16968  NCT03104439    Human PM  1
# 16969  NCT03104439      Not PM  1
# 16979  NCT03106415    Human PM  1
# 16980  NCT03106415      Not PM  1
#
# [2130 rows x 3 columns]

# %%
YEAR = 2017
path = f"../data/ct_judgement_{YEAR}/ctj_subset.pickle"

df1 = pd.read_pickle(path)
df1[df1["trec_doc_id"] == "NCT00002459"]
# Out:
# Empty DataFrame
# Columns: [trec_topic_number, trec_doc_id, pm_rel_desc, disease_desc, gene1_annotation_desc, gene1_name, gene2_annotation_desc, gene2_name, gene3_annotation_desc, gene3_name, demographics_desc, other_desc]
# Index: []

# %%
YEAR = 2018
path = f"../data/ct_judgement_{YEAR}/ctj_subset.pickle"

df1 = pd.read_pickle(path)
df1[df1["trec_doc_id"] == "NCT00002459"]
# Out:
#      trec_topic_number  trec_doc_id pm_rel_desc disease_desc  \
# 9294                34  NCT00002459      Not PM          NaN
#
#      gene1_annotation_desc gene1_name gene2_annotation_desc gene2_name  \
# 9294                   NaN        NaN                   NaN        NaN
#
#      gene3_annotation_desc gene3_name demographics_desc other_desc
# 9294                   NaN        NaN               NaN        NaN

# %%
YEAR = 2019
path = f"../data/ct_judgement_{YEAR}/ctj_subset.pickle"

df1 = pd.read_pickle(path)
df1[df1["trec_doc_id"] == "NCT00002459"]
# Out:
#      trec_topic_number  trec_doc_id pm_rel_desc disease_desc  \
# 9858                30  NCT00002459    Human PM        Exact
#
#      gene1_annotation_desc gene1_name gene2_annotation_desc gene2_name  \
# 9858          Missing Gene     PIK3R1                   NaN        NaN
#
#      gene3_annotation_desc gene3_name demographics_desc
# 9858                   NaN        NaN           Matches

# %%
YEAR = 2018
path = f"../data/pm_labels_{YEAR}/clinical_trials_judgments_{YEAR}.csv"

df1 = pd.read_csv(path)
df1[df1["trec_doc_id"] == "NCT03104335"]
# Out:
#       trec_topic_number  trec_doc_id pm_rel_desc disease_desc  \
# 9571                 34  NCT03104335      Not PM          NaN
#
#      gene1_annotation_desc gene1_name gene2_annotation_desc gene2_name  \
# 9571                   NaN        NaN                   NaN        NaN
#
#       gene3_annotation_desc  gene3_name demographics_desc other_desc
# 9571                    NaN         NaN               NaN        NaN

# %%
YEAR = 2019
path = f"../data/pm_labels_{YEAR}/clinical_trials_judgments_{YEAR}.csv"

df1 = pd.read_csv(path)
df1[df1["trec_doc_id"] == "NCT03104335"]
# Out:
#       trec_topic_number  trec_doc_id pm_rel_desc  disease_desc  \
# 1361                  4  NCT03104335    Human PM  More General
#
#      gene1_annotation_desc           gene1_name gene2_annotation_desc  \
# 1361          Missing Gene  ERBB2 amplification                   NaN
#
#      gene2_name  gene3_annotation_desc  gene3_name demographics_desc
# 1361        NaN                    NaN         NaN           Matches

# %%
df = pd.read_pickle("../data/ct_judgement_2017/all_ct_judgement_trials_2017.pickle")
print(df.id.nunique())
df.head()
# Out:
# 6656
#          score           id  \
# 0     5.448689  NCT00112463
# 1     5.448689  NCT02839707
# 2     5.448689  NCT01065805
# 3     5.448689  NCT03026881
# 4     5.448689  NCT01523639
# ...        ...          ...
# 6651  5.448689  NCT00054496
# 6652  5.448689  NCT00509431
# 6653  5.448689  NCT00884247
# 6654  5.448689  NCT01507753
# 6655  5.448689  NCT01970358
#
#                                           brief_summary  \
# 0     This phase II trial studies how well depsipept...
# 1     This randomized phase II/III trial studies how...
# 2     The Radiotracer 18F-FLT can non-invasively ass...
# 3     Fluzoparib is an oral potent, selective PARP-1...
# 4     This multicenter randomized, placebo-controlle...
# ...                                                 ...
# 6651  RATIONALE: Erlotinib may stop the growth of ca...
# 6652  RATIONALE: Erlotinib and sirolimus may stop th...
# 6653  The study aims to evaluate if a GERD treatment...
# ...

# %%
ctj = pd.read_pickle("../data/ct_judgement_2017/ctj_subset.pickle")
print(ctj.trec_doc_id.nunique())
ctj.head()
# Out:
# 6657
#   trec_topic_number  trec_doc_id pm_rel_desc disease_desc  \
# 0                 1  NCT00001188      Not PM          NaN
# 1                 1  NCT00001189      Not PM          NaN
# 2                 1  NCT00002185      Not PM          NaN
# 3                 1  NCT00002466      Not PM          NaN
# 4                 1  NCT00002641      Not PM          NaN
#
#   gene1_annotation_desc gene1_name gene2_annotation_desc gene2_name  \
# 0                   NaN        NaN                   NaN        NaN
# 1                   NaN        NaN                   NaN        NaN
# 2                   NaN        NaN                   NaN        NaN
# 3                   NaN        NaN                   NaN        NaN
# 4                   NaN        NaN                   NaN        NaN
#
#   gene3_annotation_desc gene3_name demographics_desc other_desc
# 0                   NaN        NaN               NaN        NaN
# 1                   NaN        NaN               NaN        NaN
# ...

# %%
len(set(ctj.trec_doc_id.unique()).intersection(set(df.id.unique())))
# Out:
# 6656

# %%
6657 + 6428 + 7894
# Out:
# 20979

# %%
df = pd.read_pickle("../data/all_ct_judgement_trials_all_years.pickle")
print(df.shape)
print(df.id.nunique())
df
# Out:
# (20968, 16)
# 17563
#           score           id  \
# 0      5.448689  NCT01130961
# 1      5.448689  NCT02567942
# 2      5.448689  NCT02558894
# 3      5.448689  NCT00002887
# 4      5.448689  NCT00774371
# ...         ...          ...
# 20963  5.557570  NCT00004194
# 20964  5.557570  NCT01802645
# 20965  5.557570  NCT00024258
# 20966  5.557570  NCT01835314
# 20967  5.557570  NCT02797522
#
#                                            brief_summary  \
# 0      The purpose of this study is to determine prog...
# 1      Anesthetics agents has variety inflammation du...
# 2      A Phase II Open-Label, Multi-Center Study of M...
# 3      RATIONALE: Drugs used in chemotherapy use diff...
# 4      Overweight or obesity is an established negati...
# ...                                                  ...
# 20963  RATIONALE: Fludarabine may be an effective tre...
# 20964  The aim of this study is to investigate the fo...
# 20965  RATIONALE: Drugs used in chemotherapy use diff...
# ...

# %%
check_dups = df.groupby(by=["id"]).apply(len).reset_index().sort_values(by=0)
print(check_dups[check_dups[0] == 1].shape)
print(check_dups[check_dups[0] == 2].shape)
print(check_dups[check_dups[0] == 3].shape)
# Out:
# (14650, 2)
# (2421, 2)
# (492, 2)

# %%
14650 + 2421 + 492
# Out:
# 17563

# %%
14650 + 2421*2 + 492*3
# Out:
# 20968

# %%
df_subset = df[df["id"].isin(ctj.trec_doc_id.unique())]
print(df_subset.shape)
df_subset.head()
# Out:
# (18582, 16)
#       score           id                                      brief_summary  \
# 1  5.448689  NCT02567942  Anesthetics agents has variety inflammation du...
# 2  5.448689  NCT02558894  A Phase II Open-Label, Multi-Center Study of M...
# 3  5.448689  NCT00002887  RATIONALE: Drugs used in chemotherapy use diff...
# 4  5.448689  NCT00774371  Overweight or obesity is an established negati...
# 5  5.448689  NCT02087176  A Lead-in Phase II Multicentre, Randomised, Do...
#
#                                          brief_title minimum_age  gender  \
# 1  Assessment of the Anesthetic Effect on the Act...        7300     All
# 2  Phase II Study of MEDI4736 Monotherapy or in C...        6570     All
# 3  Hydroxyurea Plus Combination Chemotherapy in P...        6570     All
# 4  Weight Reduction Intervention for Breast Cance...        6570  Female
# 5  A Placebo Controlled Study Comparing AZD1775+ ...        6570     All
#
#                                      primary_outcome  \
# ...

# %%
ctj = pd.read_pickle("../data/ctj_subset_all_years.pickle")
print(ctj.shape)
print(ctj.trec_doc_id.nunique())
ctj.head()
# Out:
# (18593, 13)
# 16507
#   demographics_desc disease_desc gene1_annotation_desc gene1_name  \
# 0               NaN          NaN                   NaN        NaN
# 1               NaN          NaN                   NaN        NaN
# 2               NaN          NaN                   NaN        NaN
# 3               NaN          NaN                   NaN        NaN
# 6               NaN          NaN                   NaN        NaN
#
#   gene2_annotation_desc gene2_name gene3_annotation_desc gene3_name  \
# 0                   NaN        NaN                   NaN        NaN
# 1                   NaN        NaN                   NaN        NaN
# 2                   NaN        NaN                   NaN        NaN
# 3                   NaN        NaN                   NaN        NaN
# 6                   NaN        NaN                   NaN        NaN
#
#   other_desc pm_rel_desc  trec_doc_id trec_topic_number  year
# 0        NaN      Not PM  NCT00001188                 1  2017
# ...

# %%
check = ctj.groupby(by=["trec_doc_id", "pm_rel_desc"]).apply(len).reset_index()
check2 = check[check.duplicated(subset=["trec_doc_id"], keep=False)]
check2
# Out:
# Empty DataFrame
# Columns: [trec_doc_id, pm_rel_desc, 0]
# Index: []

# %%
check2.shape
# Out:
# (0, 3)

# %%
def treat_dup_cases(df, doc_col, pm_col, treatment, threshold=None):
    """
    treatment: ["all", "majority"]
    threshold: [0, 1], continuous value to determine cut-off for majority
    """

    doc_pm = df.groupby(by=[doc_col, pm_col]).apply(len).reset_index()
    pm_dup = doc_pm[doc_pm.duplicated(subset=[doc_col], keep=False)]

    if treatment == "all":
        return df[~df[doc_col].isin(pm_dup[doc_col].unique())]
    else:
        pm_dup.rename(columns={0: "pm_count"}, inplace=True)
        doc_id_to_remove, doc_id_to_update = count_dups(pm_dup, doc_col, pm_col, "pm_count", threshold)

        # update PM label to the majority class
        df_clean = df[~df[doc_col].isin(doc_id_to_remove)]
        print(df_clean[doc_col].nunique())
        update_pm_label(df_clean, doc_col, pm_col, doc_id_to_update)
        print(df_clean[doc_col].nunique())

        return df_clean

def check_dup_pm_label(df):
    check = df.groupby(by=["trec_doc_id", "pm_rel_desc"]).apply(len).reset_index()
    check2 = check[check.duplicated(subset=["trec_doc_id"], keep=False)]
    return check2.shape, check2
    
def fuse_ct_info_and_ctj(ct_info_path, ctj_path):
    ctj = pd.read_pickle(ctj_path)
    ctj = treat_dup_cases(ctj, "trec_doc_id", "pm_rel_desc", treatment="all") 
    # check for duplicates with more than one pm_rel_desc label
    shape, df_check = check_dup_pm_label(ctj)
    print(shape)
    if shape[0]:
        print(df_check)
        raise ValueError("There's one doc id with different PM labels!")
    ctj.drop_duplicates(subset="trec_doc_id", inplace=True, keep="first") 
    ctj_dict = ctj.set_index("trec_doc_id", verify_integrity=True).to_dict()["pm_rel_desc"]

    ct_info = pd.read_pickle(ct_info_path)
    ct_info = ct_info[ct_info["id"].isin(ctj.trec_doc_id.unique())]
    ct_info.drop_duplicates(subset="id", inplace=True, keep="first") 
    
    ct_info["pm_rel_desc"] = ct_info["id"].map(ctj_dict)
    return ct_info

# %%
df_final = fuse_ct_info_and_ctj("../data/all_ct_judgement_trials_all_years.pickle", "../data/ctj_subset_all_years.pickle")
print(df_final.id.nunique())
print(df_final.shape)
# Out:
# (0, 3)
# 16498
# (16498, 17)

# %%
df_final.to_pickle("../data/all_ct_info_labelled.pickle")
